# %% [markdown]
# # Web Scrapping Script
# ------------------------------------

# %% [markdown]
# ## Datasets

# %% [markdown]
# Uber API - https://developer.uber.com/dashboard/
#
# Uber Rides Python SDK (beta) - https://github.com/uber/rides-python-sdk
#
# Lyft API - https://developer.lyft.com/v1/reference
#
# Weather API - https://openweathermap.org/api
#
# Yelp API - https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# As indicated in the Datasets section of this , we queried the Uber API. In order to do that, we must first register an application on Uber’s developer dashboard and install the uber-rides SDK, which is also available on Github.
#
# After successfully creating an Uber session with a server token, we found out that the Uber Ride API accepts a pair of coordinates (latitudes and longitudes) as parameters to return data on its various types of services and their price estimates.

# %%
from __future__ import print_function     #We can use print as a function.
import json
import pprint
import requests
import urllib
import os
from datetime import timedelta
import datetime                           #Allows us to use data time functions and set the date time as an index
import pandas as pd                       #to load the data file as a Pandas data frame and analyze the data
import numpy as np                        #It provides some advance math functionalities to python
import sqlite3                            #Allows us to connect to a database
from pandas.io import sql
from pandas.io.json import json_normalize

# %% [markdown]
# Getting the proper imports to run our script.

# %% [markdown]
# ## Yelp API

# %% [markdown]
# In this study, we focus on the Uber ride in Boston and Cambridge areas.
#
# We have restricted our study to these two small geographic regions due to practical issues such as analysis on a smaller region will help us to predict better with the help of other factors such as weather or popularity of places. This would provide us to provide efficient analysis with available resources.

# %% [markdown]
# We are using the Yelp Api to get the location cordinates, which will be feeded to to both the Uber and Lyft Api for price prediction.

# %%
#Boston zipcodes: http://www.city-data.com/zipmaps/Boston-Massachusetts.html

#Cambridge zipcodes: http://www2.cambridgema.gov/CityOfCambridge_Content/documents/ZipCodeMap.pdf

zipcodes = ["02108", "02109", "02110", "02111", "02113", "02114", "02115", "02116", "02118", "02119", "02120", "02121", "02122", 
            "02124", "02125", "02126", "02127", "02128", "02129", "02130", "02131", "02132", "02134", "02135", "02136", "02151", 
            "02152", "02163", "02199", "02203", "02210", "02215", "02467", "02138", "02139", "02140", "02141", "02142"]
# These are the zipcodes covering all the neighbourhoods in Boston

# %% [markdown]
# Instead of inputting random coordinates in Boston and Cambridge, which are the areas we are parameterizing, we opted to query Yelp’s API as well because it returns actual businesses’ location and thankfully the returned data contains longitudes and latitudes.

# %%
# data = {'grant_type': 'client_credentials',
#         'client_id': app_id,
#         'client_secret': app_secret}
# token = requests.post('https://api.yelp.com/oauth2/token', data=data)
# access_token = token.json()['access_token']
api_key = 'nIBG6z_BWFoH2CUvBagSh-7LNxr0UIXp0TIgnKrxDvCkBiCYu2InnKrqFvm-_KYm2a8_EBoFGiAqv5OMsdg6h38Vn-BiQNLx6hhiTgKD1F7gBKNn5SQRAJgh3EGcWnYx'
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'bearer %s' % api_key}

# Yelp v3 API: https://nz.yelp.com/developers/documentation/v3
# https://www.yelp.com/developers/documentation/v3/business_search

for z in zipcodes:   
    params = {'location': '%s' % z, # for loop of zipcodes in Boston and Cambridge
              'categories': 'active', # active stands for all businesses https://www.yelp.com/developers/documentation/v3/all_category_list
              'limit': 50} # maximum 50
    
response = requests.get(url=url, params=params, headers=headers) #request.get allows us to make clean http requests to the api

results = response.json()['businesses']  # getting the json file for the above paramenters
for business in results:
     print(business['name'], business['location'])

print ('\nTotal Businesses retrieved:', len(results))


conn = sqlite3.connect('yelp.db')     #conn allows us to connect to the yelp database to query location information
cur = conn.cursor()


# normalizing json to pandas dataframe
df = json_normalize(results)

df = df.drop(['categories', 'location.display_address', 'transactions'], axis=1)

#Renaming the columns
df.columns = df.columns.str.replace(r'[.]', '_')

# converting to sqlite
df.to_sql("yelp_businesses", conn, if_exists="replace")

#Getting the data into our dataframe
pd.read_sql_query("select * from yelp_businesses;", conn)
# Out:
# Cambridge Center Roof Garden {'address1': '4 Cambridge Ctr', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02142', 'country': 'US', 'state': 'MA', 'display_address': ['4 Cambridge Ctr', 'Cambridge, MA 02142']}
# Boston Common {'address1': 'Beacon St', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['Beacon St', 'Boston, MA 02139']}
# Trapology Boston {'address1': '177 Tremont St', 'address2': 'Fl 2', 'address3': '', 'city': 'Boston', 'zip_code': '02111', 'country': 'US', 'state': 'MA', 'display_address': ['177 Tremont St', 'Fl 2', 'Boston, MA 02111']}
# Community Ice Skating at Kendall Square {'address1': '300 Athenaeum St', 'address2': None, 'address3': '', 'city': 'Cambridge', 'zip_code': '02142', 'country': 'US', 'state': 'MA', 'display_address': ['300 Athenaeum St', 'Cambridge, MA 02142']}
# Btone Fitness - Back Bay {'address1': '30 Newbury St', 'address2': 'Fl 4', 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['30 Newbury St', 'Fl 4', 'Boston, MA 02116']}
# Charles River Bike Paths {'address1': 'Storrow And Memorial Dr', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02228', 'country': 'US', 'state': 'MA', 'display_address': ['Storrow And Memorial Dr', 'Boston, MA 02228']}
# Turnstyle - Kendall Square {'address1': 'One Kendall Square', 'address2': 'Ste B3002', 'address3': '', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['One Kendall Square', 'Ste B3002', 'Cambridge, MA 02139']}
# BodyScapes Fitness {'address1': '356 Third St', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02142', 'country': 'US', 'state': 'MA', 'display_address': ['356 Third St', 'Cambridge, MA 02142']}
# The Charles River {'address1': 'Storrow Dr', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02114', 'country': 'US', 'state': 'MA', 'display_address': ['Storrow Dr', 'Boston, MA 02114']}
# Cambridge Athletic Club {'address1': '215 First St', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02142', 'country': 'US', 'state': 'MA', 'display_address': ['215 First St', 'Cambridge, MA 02142']}
# Achieve Fitness {'address1': '42 Merriam St', 'address2': None, 'address3': '', 'city': 'Somerville', 'zip_code': '02143', 'country': 'US', 'state': 'MA', 'display_address': ['42 Merriam St', 'Somerville, MA 02143']}
# Urban AdvenTours {'address1': '103 Atlantic Ave', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02110', 'country': 'US', 'state': 'MA', 'display_address': ['103 Atlantic Ave', 'Boston, MA 02110']}
# YogaWorks Back Bay {'address1': '364 Boylston St', 'address2': 'Fl 2', 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['364 Boylston St', 'Fl 2', 'Boston, MA 02116']}
# Community Boating {'address1': '21 David G Mugar Way', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02114', 'country': 'US', 'state': 'MA', 'display_address': ['21 David G Mugar Way', 'Boston, MA 02114']}
# Broadway Bicycle School {'address1': '351 Broadway', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['351 Broadway', 'Cambridge, MA 02139']}
# The Breathing Room {'address1': '763 Massachusetts Ave', 'address2': 'Ste 7', 'address3': '', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['763 Massachusetts Ave', 'Ste 7', 'Cambridge, MA 02139']}
# The Dance Complex {'address1': '536 Massachusetts Ave', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['536 Massachusetts Ave', 'Cambridge, MA 02139']}
# Escape The Room Boston {'address1': '33 West Street', 'address2': 'Floor 3', 'address3': '', 'city': 'Boston', 'zip_code': '02111', 'country': 'US', 'state': 'MA', 'display_address': ['33 West Street', 'Floor 3', 'Boston, MA 02111']}
# Healthworks Fitness Center {'address1': '441 Stuart St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['441 Stuart St', 'Boston, MA 02116']}
# Redline Fight Sports {'address1': '614 Massachusetts Ave', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['614 Massachusetts Ave', 'Cambridge, MA 02139']}
# Prana Power Yoga {'address1': '585 Mass Ave', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['585 Mass Ave', 'Cambridge, MA 02139']}
# Exhale Back Bay {'address1': '28 Arlington St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['28 Arlington St', 'Boston, MA 02116']}
# Swet Studio {'address1': '480 Tremont St', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['480 Tremont St', 'Boston, MA 02116']}
# Kings Dining & Entertainment - Boston Back Bay {'address1': '50 Dalton St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02115', 'country': 'US', 'state': 'MA', 'display_address': ['50 Dalton St', 'Boston, MA 02115']}
# Freedom Trail Run {'address1': 'Park & Tremont St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02108', 'country': 'US', 'state': 'MA', 'display_address': ['Park & Tremont St', 'Boston, MA 02108']}
# Cambridge Bicycle {'address1': '259 Massachusetts Ave', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['259 Massachusetts Ave', 'Cambridge, MA 02139']}
# Charles River Canoe & Kayak {'address1': '15 Broad Canal Way', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02142', 'country': 'US', 'state': 'MA', 'display_address': ['15 Broad Canal Way', 'Cambridge, MA 02142']}
# Joint Ventures Physical Therapy and Fitness {'address1': '654 Beacon St', 'address2': 'Fl 2', 'address3': 'Kenmore Square', 'city': 'Boston', 'zip_code': '02215', 'country': 'US', 'state': 'MA', 'display_address': ['654 Beacon St', 'Fl 2', 'Kenmore Square', 'Boston, MA 02215']}
# Flywheel Sports - Back Bay {'address1': '800 Boylston St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02199', 'country': 'US', 'state': 'MA', 'display_address': ['800 Boylston St', 'Boston, MA 02199']}
# BollyX {'address1': '536 Massachusetts Ave', 'address2': '', 'address3': 'The Dance Complex', 'city': 'Cambridge', 'zip_code': '02139', 'country': 'US', 'state': 'MA', 'display_address': ['536 Massachusetts Ave', 'The Dance Complex', 'Cambridge, MA 02139']}
# Shakespeare on the Common {'address1': 'Boston Common', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['Boston Common', 'Boston, MA 02116']}
# Georges Island {'address1': '', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02228', 'country': 'US', 'state': 'MA', 'display_address': ['Boston, MA 02228']}
# Raw Fitness Performance {'address1': "201 Monsignor O'Brien Hwy", 'address2': None, 'address3': '', 'city': 'Cambridge', 'zip_code': '02141', 'country': 'US', 'state': 'MA', 'display_address': ["201 Monsignor O'Brien Hwy", 'Cambridge, MA 02141']}
# Barry's Bootcamp {'address1': '30 Chauncy St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02111', 'country': 'US', 'state': 'MA', 'display_address': ['30 Chauncy St', 'Boston, MA 02111']}
# The Boston Common Frog Pond {'address1': 'Beacon St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02108', 'country': 'US', 'state': 'MA', 'display_address': ['Beacon St', 'Boston, MA 02108']}
# The Bar Method {'address1': '234 Clarendon St', 'address2': 'Fl 2', 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['234 Clarendon St', 'Fl 2', 'Boston, MA 02116']}
# Orangetheory Fitness Cambridge - Kendall Square {'address1': '270 Third St', 'address2': None, 'address3': None, 'city': 'Cambridge', 'zip_code': '02142', 'country': 'US', 'state': 'MA', 'display_address': ['270 Third St', 'Cambridge, MA 02142']}
# Lucky Strike {'address1': '145 Ipswich St', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02215', 'country': 'US', 'state': 'MA', 'display_address': ['145 Ipswich St', 'Boston, MA 02215']}
# Pure Barre - Boston {'address1': '350 Newbury St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02115', 'country': 'US', 'state': 'MA', 'display_address': ['350 Newbury St', 'Boston, MA 02115']}
# Commonwealth Avenue Mall {'address1': '484 Commonwealth Ave', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['484 Commonwealth Ave', 'Boston, MA 02116']}
# North Point Park {'address1': '6 Museum Way', 'address2': '', 'address3': '', 'city': 'Cambridge', 'zip_code': '02141', 'country': 'US', 'state': 'MA', 'display_address': ['6 Museum Way', 'Cambridge, MA 02141']}
# Boxaroo {'address1': '55 Court St', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02108', 'country': 'US', 'state': 'MA', 'display_address': ['55 Court St', 'Boston, MA 02108']}
# Copley Square {'address1': '560 Boylston St', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['560 Boylston St', 'Boston, MA 02116']}
# Innercity Weightlifting {'address1': '', 'address2': None, 'address3': '', 'city': 'Cambridge', 'zip_code': '02142', 'country': 'US', 'state': 'MA', 'display_address': ['Cambridge, MA 02142']}
# Balans Wellness Studio {'address1': '376 Boylston St', 'address2': '', 'address3': 'Third Fl', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['376 Boylston St', 'Third Fl', 'Boston, MA 02116']}
# 305 Fitness {'address1': '699 Boylston St', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['699 Boylston St', 'Boston, MA 02116']}
# Cashunt Boston {'address1': '22-24 Clinton St', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02109', 'country': 'US', 'state': 'MA', 'display_address': ['22-24 Clinton St', 'Boston, MA 02109']}
# Cyc Fitness {'address1': '699 Boylston St.', 'address2': None, 'address3': '', 'city': 'Boston', 'zip_code': '02116', 'country': 'US', 'state': 'MA', 'display_address': ['699 Boylston St.', 'Boston, MA 02116']}
# CrossFit Fenway {'address1': '100 Brookline Ave', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02215', 'country': 'US', 'state': 'MA', 'display_address': ['100 Brookline Ave', 'Boston, MA 02215']}
# Social Boston Sports {'address1': '', 'address2': '', 'address3': '', 'city': 'Boston', 'zip_code': '02112', 'country': 'US', 'state': 'MA', 'display_address': ['Boston, MA 02112']}
#
# Total Businesses retrieved: 50
#     index                                              alias  \
# 0       0             cambridge-center-roof-garden-cambridge
# 1       1                               boston-common-boston
# 2       2                            trapology-boston-boston
# 3       3  community-ice-skating-at-kendall-square-cambridge
# 4       4                      btone-fitness-back-bay-boston
# 5       5                    charles-river-bike-paths-boston
# 6       6               turnstyle-kendall-square-cambridge-2
# 7       7                       bodyscapes-fitness-cambridge
# 8       8                           the-charles-river-boston
# 9       9                  cambridge-athletic-club-cambridge
# 10     10                         achieve-fitness-somerville
# 11     11                            urban-adventours-boston
# 12     12                          yogaworks-back-bay-boston
# 13     13                         community-boating-boston-3
# 14     14                  broadway-bicycle-school-cambridge
# 15     15                     the-breathing-room-cambridge-2
# 16     16                        the-dance-complex-cambridge
# 17     17                      escape-the-room-boston-boston
# 18     18                  healthworks-fitness-center-boston
# 19     19                     redline-fight-sports-cambridge
# 20     20                         prana-power-yoga-cambridge
# 21     21                             exhale-back-bay-boston
# 22     22                                 swet-studio-boston
# 23     23  kings-dining-and-entertainment-boston-back-bay...
# 24     24                           freedom-trail-run-boston
# 25     25                        cambridge-bicycle-cambridge
# 26     26          charles-river-canoe-and-kayak-cambridge-2
# 27     27  joint-ventures-physical-therapy-and-fitness-bo...
# 28     28                    flywheel-sports-back-bay-boston
# 29     29                                   bollyx-cambridge
# 30     30                   shakespeare-on-the-common-boston
# 31     31                              georges-island-boston
# 32     32                raw-fitness-performance-cambridge-2
# 33     33                             barrys-bootcamp-boston
# 34     34                 the-boston-common-frog-pond-boston
# 35     35                            the-bar-method-boston-3
# 36     36  orangetheory-fitness-cambridge-kendall-square-...
# 37     37                                lucky-strike-boston
# 38     38                           pure-barre-boston-boston
# 39     39                    commonwealth-avenue-mall-boston
# 40     40                         north-point-park-cambridge
# 41     41                                   boxaroo-boston-3
# 42     42                               copley-square-boston
# 43     43                innercity-weightlifting-cambridge-3
# 44     44                    balans-wellness-studio-boston-3
# 45     45                                 305-fitness-boston
# 46     46                            cashunt-boston-boston-2
# 47     47                                 cyc-fitness-boston
# 48     48                             crossfit-fenway-boston
# 49     49                        social-boston-sports-boston
#
#     coordinates_latitude  coordinates_longitude   display_phone     distance  \
# 0              42.363166             -71.086729                   233.226556
# 1              42.355373             -71.065750  (304) 563-4951  1801.659734
# 2              42.353014             -71.064216  (857) 285-2085  2055.066728
# 3              42.364580             -71.081500  (617) 492-0941   233.540483
# 4              42.352040             -71.072590  (617) 578-8663  1647.815650
# 5              42.360307             -71.072563                  1046.413810
# 6              42.366570             -71.090190  (617) 531-8922   601.138535
# 7              42.363680             -71.083410  (617) 252-0020    81.803994
# 8              42.361275             -71.074905                   827.063258
# 9              42.364220             -71.078540  (617) 491-8989   462.581625
# 10             42.377843             -71.091881  (617) 616-5801  1650.659960
# 11             42.361652             -71.052037  (617) 670-0637  2624.566555
# 12             42.351364             -71.071510  (617) 375-9642  1761.622058
# 13             42.359855             -71.073094  (617) 523-1038  1028.883562
# 14             42.370460             -71.103520  (617) 868-3392  1735.354615
# 15             42.366094             -71.104862  (617) 977-4836  1711.339329
# 16             42.364348             -71.102258  (617) 547-9363  1486.352935
# 17             42.354981             -71.062477  (857) 256-1174  2055.120172
# 18             42.348709             -71.075768  (617) 859-7700  1848.962538
# 19             42.364987             -71.103281  (617) 868-2275  1592.847612
# 20             42.365095             -71.102730  (617) 641-9642  1525.917540
# 21             42.351681             -71.070530  (617) 532-7000  1812.151670
# 22             42.346026             -71.069174  (617) 670-0631  2361.665598
# 23             42.347060             -71.085650  (617) 266-2695  1901.242623
# 24             42.356484             -71.062267  (617) 398-0611  1992.580464
# 25             42.361760             -71.097150  (617) 876-6555  1110.848816
# 26             42.363046             -71.082354  (617) 965-5110   222.605549
# 27             42.349390             -71.095900  (617) 536-1161  1895.225116
# 28             42.348733             -71.082978  (617) 300-0388  1714.368435
# 29             42.364282             -71.102211                  1479.560045
# 30             42.358650             -71.057850  (617) 426-0863  1828.957525
# 31             42.358333             -71.060278                  2103.829694
# 32             42.372450             -71.079150  (617) 913-8401  1019.661467
# 33             42.353988             -71.059862  (857) 350-4019  2295.743769
# 34             42.355912             -71.065922  (617) 635-2120  1757.925974
# 35             42.351700             -71.075990  (617) 236-4455  1536.523793
# 36             42.366037             -71.082013  (617) 714-5280   278.622244
# 37             42.347409             -71.094304  (617) 437-0300  2039.830643
# 38             42.348163             -71.087276  (617) 247-5360  1792.668176
# 39             42.348503             -71.094223  (617) 635-4500  1382.078867
# 40             42.369471             -71.071739  (617) 523-2900  1111.639454
# 41             42.359279             -71.059424  (617) 249-5280  2106.013266
# 42             42.350064             -71.076114                  1698.873994
# 43             42.363700             -71.082830  (443) 610-0440   155.220469
# 44             42.351316             -71.071671  (617) 450-8333  1757.490612
# 45             42.349877             -71.079251  (617) 603-2522  1635.656527
# 46             42.353068             -71.076519  (866) 276-4733  1382.078867
# 47             42.349860             -71.079230  (857) 305-5671  1635.214088
# 48             42.346112             -71.099559  (617) 266-7700  2367.176872
# 49             42.360351             -71.060042  (888) 727-2005  2029.023790
#
#                         id                                          image_url  \
# 0   x4vRczmgp446CdsDiJCUag  https://s3-media2.fl.yelpcdn.com/bphoto/4znlgU...
# 1   QFq8CccuRrEq9MsTUCnD9Q  https://s3-media1.fl.yelpcdn.com/bphoto/Jhx9n_...
# 2   FaJGhYEOaYso9uKSYMAgbg  https://s3-media4.fl.yelpcdn.com/bphoto/s7_-qt...
# 3   wI6WwxkMwt4jFJrx16jNSA  https://s3-media2.fl.yelpcdn.com/bphoto/kd84-n...
# 4   cZOzUfwPz8ANog-8nWzhRw  https://s3-media4.fl.yelpcdn.com/bphoto/I3gcI1...
# 5   WGqocG3zwHIsNb_dFNTF8A  https://s3-media2.fl.yelpcdn.com/bphoto/HrngKN...
# 6   fF1MNu2TTDTNsLqx4u_80w  https://s3-media3.fl.yelpcdn.com/bphoto/J1k6jd...
# 7   ztZgacrzSQam20TVYZbKKQ  https://s3-media2.fl.yelpcdn.com/bphoto/Xt74Ot...
# 8   06jyL7iohG-Kvu7iiJblGg  https://s3-media4.fl.yelpcdn.com/bphoto/9-DD7M...
# 9   37jNprFs5eS7sHwqllcSrA  https://s3-media3.fl.yelpcdn.com/bphoto/r7Ot1O...
# 10  ou0uHPUJN-TiT9JIyQb5fA  https://s3-media2.fl.yelpcdn.com/bphoto/nNxEZR...
# 11  sxJQzTN6Iy9DQwFBHGhWbw  https://s3-media3.fl.yelpcdn.com/bphoto/rTfwxZ...
# 12  7be4ftkZW_2cwNOihjrBSw  https://s3-media1.fl.yelpcdn.com/bphoto/H0JBGt...
# 13  4Xj5QuaOdtSAPr7dhxZZVg  https://s3-media2.fl.yelpcdn.com/bphoto/BDTU1P...
# 14  ObCoEc3ii1EY75etMxRILQ  https://s3-media1.fl.yelpcdn.com/bphoto/Oby6AD...
# 15  BvfRqWtD3smJ0wJFIXe8FA  https://s3-media2.fl.yelpcdn.com/bphoto/6Vms2h...
# 16  ZYxgGWv5RGeJ9FbtGmSWaA  https://s3-media1.fl.yelpcdn.com/bphoto/6tvQoN...
# 17  z-jj0ixv-2Wj3pgcKzsaOA  https://s3-media3.fl.yelpcdn.com/bphoto/AlaCif...
# 18  Iftn89amEiaXRd1WKXLauQ  https://s3-media1.fl.yelpcdn.com/bphoto/VIGphI...
# 19  6EB64SrQIE-QZx_kZN_1jQ  https://s3-media3.fl.yelpcdn.com/bphoto/mxKIN0...
# 20  -sBRtVo0bwLAtru_-iFmcw  https://s3-media2.fl.yelpcdn.com/bphoto/ZmHuj-...
# 21  9rx9UJTz4Ph_xXd4PzjR6g  https://s3-media4.fl.yelpcdn.com/bphoto/T5JVZE...
# 22  frrN6_NcOjKmHH6ogdACJQ  https://s3-media2.fl.yelpcdn.com/bphoto/WbJdRw...
# 23  TLtykd3vG5_BG-8MP66RHg  https://s3-media2.fl.yelpcdn.com/bphoto/n8uXe8...
# 24  hkOEXa3etk3p7203RtDDFA  https://s3-media1.fl.yelpcdn.com/bphoto/KdZa-a...
# 25  07VwweSmOMqPuFbi9MO4fw  https://s3-media3.fl.yelpcdn.com/bphoto/PSrRax...
# 26  1do2Cl_u1bTOflTDQJJtSQ  https://s3-media2.fl.yelpcdn.com/bphoto/dZrwUw...
# 27  lfVF5vUWopxYVp0ThD70hQ  https://s3-media1.fl.yelpcdn.com/bphoto/KKspQx...
# 28  E1ho2mhfT_JZljkUkV4uoA  https://s3-media3.fl.yelpcdn.com/bphoto/iThJgv...
# 29  qvsE4roSD2tmh9no9DllbA  https://s3-media1.fl.yelpcdn.com/bphoto/CDymKD...
# 30  6UT_zi7ntsF3uu1EEv2hEg  https://s3-media2.fl.yelpcdn.com/bphoto/aH3ybD...
# 31  4DmP5q2B99duLiz__jJCgQ  https://s3-media4.fl.yelpcdn.com/bphoto/lL95rq...
# 32  8JlDnU8Xf0FHAHYQg6Ds9Q  https://s3-media1.fl.yelpcdn.com/bphoto/TmD3P2...
# 33  I4ixVMDf4P5iJa6XbgnLrg  https://s3-media2.fl.yelpcdn.com/bphoto/boPjFz...
# 34  n9nvM67G7x5ReNz3daRXXQ  https://s3-media4.fl.yelpcdn.com/bphoto/sayVAL...
# 35  x1Gk0h1Z6o3nO33j899b2w  https://s3-media3.fl.yelpcdn.com/bphoto/bhur6j...
# 36  uIuuUTRjJaq_niMS-XXxSQ  https://s3-media2.fl.yelpcdn.com/bphoto/BO5fQF...
# 37  yKvlRknp1Feues1rG-aJlg  https://s3-media3.fl.yelpcdn.com/bphoto/mW5rtj...
# 38  gezMBoTIb0dwtyJ4V1lsaA  https://s3-media1.fl.yelpcdn.com/bphoto/NuPZ-7...
# 39  GzMvBTRILnGzXtPCJn981Q  https://s3-media3.fl.yelpcdn.com/bphoto/yWYOsJ...
# 40  9YbGMgJ3cVR1mLVGjRhb3Q  https://s3-media4.fl.yelpcdn.com/bphoto/zPe_b7...
# 41  ptmMsgVZsPqhEAukcjRRuw  https://s3-media2.fl.yelpcdn.com/bphoto/KBVUyX...
# 42  AIBp7CZNAqzLlLc_Kpc9JA  https://s3-media4.fl.yelpcdn.com/bphoto/q4lc64...
# 43  CMGgEWagpB----KRXZlGUQ  https://s3-media1.fl.yelpcdn.com/bphoto/5_a5g1...
# 44  1LYOfO6tzvBJCqNOJNVQlw  https://s3-media2.fl.yelpcdn.com/bphoto/rGZ4Lv...
# 45  qUJCmkORzZWMzTvV33GReQ  https://s3-media2.fl.yelpcdn.com/bphoto/4J89yw...
# 46  gr5MTMgBR1oaswzndx3wSA  https://s3-media1.fl.yelpcdn.com/bphoto/QhPAk9...
# 47  LbaV1rbAhQCDDwJ_wxz3Vg  https://s3-media2.fl.yelpcdn.com/bphoto/xqv1aN...
# 48  Qdp39yK3caz4X2nBzwKylQ  https://s3-media3.fl.yelpcdn.com/bphoto/4I_33H...
# 49  Jvpsf1kV81R2DlX_m7pP1Q  https://s3-media4.fl.yelpcdn.com/bphoto/HuJ2NS...
#
#     is_closed          location_address1  \
# 0           0            4 Cambridge Ctr
# 1           0                  Beacon St
# 2           0             177 Tremont St
# 3           0           300 Athenaeum St
# 4           0              30 Newbury St
# 5           0    Storrow And Memorial Dr
# 6           0         One Kendall Square
# 7           0               356 Third St
# 8           0                 Storrow Dr
# 9           0               215 First St
# 10          0              42 Merriam St
# 11          0           103 Atlantic Ave
# 12          0            364 Boylston St
# 13          0       21 David G Mugar Way
# 14          0               351 Broadway
# 15          0      763 Massachusetts Ave
# 16          0      536 Massachusetts Ave
# 17          0             33 West Street
# 18          0              441 Stuart St
# 19          0      614 Massachusetts Ave
# 20          0               585 Mass Ave
# 21          0            28 Arlington St
# 22          0             480 Tremont St
# 23          0               50 Dalton St
# 24          0          Park & Tremont St
# 25          0      259 Massachusetts Ave
# 26          0         15 Broad Canal Way
# 27          0              654 Beacon St
# 28          0            800 Boylston St
# 29          0      536 Massachusetts Ave
# 30          0              Boston Common
# 31          0
# 32          0  201 Monsignor O'Brien Hwy
# 33          0              30 Chauncy St
# 34          0                  Beacon St
# 35          0           234 Clarendon St
# 36          0               270 Third St
# 37          0             145 Ipswich St
# 38          0             350 Newbury St
# 39          0       484 Commonwealth Ave
# 40          0               6 Museum Way
# 41          0                55 Court St
# 42          0            560 Boylston St
# 43          0
# 44          0            376 Boylston St
# 45          0            699 Boylston St
# 46          0           22-24 Clinton St
# 47          0           699 Boylston St.
# 48          0          100 Brookline Ave
# 49          0
#
#                           ...                         location_city  \
# 0                         ...                             Cambridge
# 1                         ...                                Boston
# 2                         ...                                Boston
# 3                         ...                             Cambridge
# 4                         ...                                Boston
# 5                         ...                                Boston
# 6                         ...                             Cambridge
# 7                         ...                             Cambridge
# 8                         ...                                Boston
# 9                         ...                             Cambridge
# 10                        ...                            Somerville
# 11                        ...                                Boston
# 12                        ...                                Boston
# 13                        ...                                Boston
# 14                        ...                             Cambridge
# 15                        ...                             Cambridge
# 16                        ...                             Cambridge
# 17                        ...                                Boston
# 18                        ...                                Boston
# 19                        ...                             Cambridge
# 20                        ...                             Cambridge
# 21                        ...                                Boston
# 22                        ...                                Boston
# 23                        ...                                Boston
# 24                        ...                                Boston
# 25                        ...                             Cambridge
# 26                        ...                             Cambridge
# 27                        ...                                Boston
# 28                        ...                                Boston
# 29                        ...                             Cambridge
# 30                        ...                                Boston
# 31                        ...                                Boston
# 32                        ...                             Cambridge
# 33                        ...                                Boston
# 34                        ...                                Boston
# 35                        ...                                Boston
# 36                        ...                             Cambridge
# 37                        ...                                Boston
# 38                        ...                                Boston
# 39                        ...                                Boston
# 40                        ...                             Cambridge
# 41                        ...                                Boston
# 42                        ...                                Boston
# 43                        ...                             Cambridge
# 44                        ...                                Boston
# 45                        ...                                Boston
# 46                        ...                                Boston
# 47                        ...                                Boston
# 48                        ...                                Boston
# 49                        ...                                Boston
#
#    location_country location_state location_zip_code  \
# 0                US             MA             02142
# 1                US             MA             02139
# 2                US             MA             02111
# 3                US             MA             02142
# 4                US             MA             02116
# 5                US             MA             02228
# 6                US             MA             02139
# 7                US             MA             02142
# 8                US             MA             02114
# 9                US             MA             02142
# 10               US             MA             02143
# 11               US             MA             02110
# 12               US             MA             02116
# 13               US             MA             02114
# 14               US             MA             02139
# 15               US             MA             02139
# 16               US             MA             02139
# 17               US             MA             02111
# 18               US             MA             02116
# 19               US             MA             02139
# 20               US             MA             02139
# 21               US             MA             02116
# 22               US             MA             02116
# 23               US             MA             02115
# 24               US             MA             02108
# 25               US             MA             02139
# 26               US             MA             02142
# 27               US             MA             02215
# 28               US             MA             02199
# 29               US             MA             02139
# 30               US             MA             02116
# 31               US             MA             02228
# 32               US             MA             02141
# 33               US             MA             02111
# 34               US             MA             02108
# 35               US             MA             02116
# 36               US             MA             02142
# 37               US             MA             02215
# 38               US             MA             02115
# 39               US             MA             02116
# 40               US             MA             02141
# 41               US             MA             02108
# 42               US             MA             02116
# 43               US             MA             02142
# 44               US             MA             02116
# 45               US             MA             02116
# 46               US             MA             02109
# 47               US             MA             02116
# 48               US             MA             02215
# 49               US             MA             02112
#
#                                                name         phone price  \
# 0                      Cambridge Center Roof Garden                None
# 1                                     Boston Common  +13045634951  None
# 2                                  Trapology Boston  +18572852085  None
# 3           Community Ice Skating at Kendall Square  +16174920941  None
# 4                          Btone Fitness - Back Bay  +16175788663  None
# 5                          Charles River Bike Paths                None
# 6                        Turnstyle - Kendall Square  +16175318922  None
# 7                                BodyScapes Fitness  +16172520020  None
# 8                                 The Charles River                None
# 9                           Cambridge Athletic Club  +16174918989  None
# 10                                  Achieve Fitness  +16176165801  None
# 11                                 Urban AdvenTours  +16176700637  None
# 12                               YogaWorks Back Bay  +16173759642  None
# 13                                Community Boating  +16175231038  None
# 14                          Broadway Bicycle School  +16178683392    $$
# 15                               The Breathing Room  +16179774836    $$
# 16                                The Dance Complex  +16175479363  None
# 17                           Escape The Room Boston  +18572561174  None
# 18                       Healthworks Fitness Center  +16178597700  None
# 19                             Redline Fight Sports  +16178682275  None
# 20                                 Prana Power Yoga  +16176419642  None
# 21                                  Exhale Back Bay  +16175327000   $$$
# 22                                      Swet Studio  +16176700631  None
# 23   Kings Dining & Entertainment - Boston Back Bay  +16172662695    $$
# 24                                Freedom Trail Run  +16173980611  None
# 25                                Cambridge Bicycle  +16178766555    $$
# 26                      Charles River Canoe & Kayak  +16179655110  None
# 27      Joint Ventures Physical Therapy and Fitness  +16175361161    $$
# 28                       Flywheel Sports - Back Bay  +16173000388  None
# 29                                           BollyX                None
# 30                        Shakespeare on the Common  +16174260863  None
# 31                                   Georges Island                None
# 32                          Raw Fitness Performance  +16179138401  None
# 33                                 Barry's Bootcamp  +18573504019  None
# 34                      The Boston Common Frog Pond  +16176352120  None
# 35                                   The Bar Method  +16172364455  None
# 36  Orangetheory Fitness Cambridge - Kendall Square  +16177145280  None
# 37                                     Lucky Strike  +16174370300    $$
# 38                              Pure Barre - Boston  +16172475360  None
# 39                         Commonwealth Avenue Mall  +16176354500  None
# 40                                 North Point Park  +16175232900  None
# 41                                          Boxaroo  +16172495280  None
# 42                                    Copley Square                None
# 43                          Innercity Weightlifting  +14436100440  None
# 44                           Balans Wellness Studio  +16174508333  None
# 45                                      305 Fitness  +16176032522  None
# 46                                   Cashunt Boston  +18662764733  None
# 47                                      Cyc Fitness  +18573055671  None
# 48                                  CrossFit Fenway  +16172667700  None
# 49                             Social Boston Sports  +18887272005  None
#
#    rating review_count                                                url
# 0     5.0           56  https://www.yelp.com/biz/cambridge-center-roof...
# 1     4.5          397  https://www.yelp.com/biz/boston-common-boston?...
# 2     5.0          135  https://www.yelp.com/biz/trapology-boston-bost...
# 3     4.5           35  https://www.yelp.com/biz/community-ice-skating...
# 4     4.5          176  https://www.yelp.com/biz/btone-fitness-back-ba...
# 5     4.5           77  https://www.yelp.com/biz/charles-river-bike-pa...
# 6     4.0           69  https://www.yelp.com/biz/turnstyle-kendall-squ...
# 7     4.5           26  https://www.yelp.com/biz/bodyscapes-fitness-ca...
# 8     4.5           42  https://www.yelp.com/biz/the-charles-river-bos...
# 9     4.0           46  https://www.yelp.com/biz/cambridge-athletic-cl...
# 10    5.0           62  https://www.yelp.com/biz/achieve-fitness-somer...
# 11    4.5          161  https://www.yelp.com/biz/urban-adventours-bost...
# 12    4.0          226  https://www.yelp.com/biz/yogaworks-back-bay-bo...
# 13    4.5           57  https://www.yelp.com/biz/community-boating-bos...
# 14    4.5          128  https://www.yelp.com/biz/broadway-bicycle-scho...
# 15    5.0           63  https://www.yelp.com/biz/the-breathing-room-ca...
# 16    4.5           73  https://www.yelp.com/biz/the-dance-complex-cam...
# 17    4.5          135  https://www.yelp.com/biz/escape-the-room-bosto...
# 18    4.0          161  https://www.yelp.com/biz/healthworks-fitness-c...
# 19    4.5           46  https://www.yelp.com/biz/redline-fight-sports-...
# 20    4.0          123  https://www.yelp.com/biz/prana-power-yoga-camb...
# 21    3.5          270  https://www.yelp.com/biz/exhale-back-bay-bosto...
# 22    4.5           75  https://www.yelp.com/biz/swet-studio-boston?ad...
# 23    3.0          427  https://www.yelp.com/biz/kings-dining-and-ente...
# 24    5.0           36  https://www.yelp.com/biz/freedom-trail-run-bos...
# 25    3.0          182  https://www.yelp.com/biz/cambridge-bicycle-cam...
# 26    4.5          101  https://www.yelp.com/biz/charles-river-canoe-a...
# 27    4.5           53  https://www.yelp.com/biz/joint-ventures-physic...
# 28    4.0          104  https://www.yelp.com/biz/flywheel-sports-back-...
# 29    5.0           29  https://www.yelp.com/biz/bollyx-cambridge?adju...
# 30    4.5           40  https://www.yelp.com/biz/shakespeare-on-the-co...
# 31    4.5           52  https://www.yelp.com/biz/georges-island-boston...
# 32    5.0           15  https://www.yelp.com/biz/raw-fitness-performan...
# 33    4.5           75  https://www.yelp.com/biz/barrys-bootcamp-bosto...
# 34    4.0           90  https://www.yelp.com/biz/the-boston-common-fro...
# 35    4.0           86  https://www.yelp.com/biz/the-bar-method-boston...
# 36    4.0           21  https://www.yelp.com/biz/orangetheory-fitness-...
# 37    2.5          433  https://www.yelp.com/biz/lucky-strike-boston?a...
# 38    4.5           46  https://www.yelp.com/biz/pure-barre-boston-bos...
# 39    4.5           20  https://www.yelp.com/biz/commonwealth-avenue-m...
# 40    4.5           22  https://www.yelp.com/biz/north-point-park-camb...
# 41    5.0           27  https://www.yelp.com/biz/boxaroo-boston-3?adju...
# 42    4.0           44  https://www.yelp.com/biz/copley-square-boston?...
# 43    5.0           10  https://www.yelp.com/biz/innercity-weightlifti...
# 44    5.0           25  https://www.yelp.com/biz/balans-wellness-studi...
# 45    5.0           28  https://www.yelp.com/biz/305-fitness-boston?ad...
# 46    5.0           20  https://www.yelp.com/biz/cashunt-boston-boston...
# 47    4.0           47  https://www.yelp.com/biz/cyc-fitness-boston?ad...
# 48    4.5           25  https://www.yelp.com/biz/crossfit-fenway-bosto...
# 49    4.0           38  https://www.yelp.com/biz/social-boston-sports-...
#
# [50 rows x 22 columns]

# %% [markdown]
# We are using api to scrap the data within the parameters i.e. zipcodes, and then we convert the json file to our dataframe.

# %% [markdown]
# ## Uber API

# %% [markdown]
# Using the proper import methods to call the api.

# %%
# pip install uber-rides
from uber_rides.session import Session as uber_Session
from uber_rides.client import UberRidesClient
# conda install -c conda-forge geopy
from geopy.distance import vincenty
import csv

session = uber_Session(server_token='Uvu3eEPnLtPKCbTU7KrCko5jo1ua4CVgYAqd0JfO')
client = UberRidesClient(session)

# %% [markdown]
# Getting the source and destination coordinates for the API using our yelp database.

# %%
#Querying the database to get the required informarion from the database for the source
df1 = pd.read_sql_query("SELECT name, coordinates_latitude, coordinates_longitude, location_address1, location_address2, location_address3, location_city, location_state, location_zip_code, location_country FROM yelp_businesses ORDER BY RANDOM() LIMIT 1;", conn)
df1.head()

#Querying the database to get the required informarion from the database for the destination
df2 = pd.read_sql_query('SELECT name, coordinates_latitude, coordinates_longitude, location_address1, location_address2, location_address3, location_city, location_state, location_zip_code, location_country FROM yelp_businesses where name IN (SELECT name FROM yelp_businesses ORDER BY RANDOM() LIMIT 1)', conn)
df2.head()

#Since we only need the coordinates of the location we store it in an array, for ease of use
start_loc = (df1['coordinates_latitude'][0], df1['coordinates_longitude'][0])
start_loc

end_loc = (df2['coordinates_latitude'][0], df2['coordinates_longitude'][0])
end_loc
# Out:
# (42.3637, -71.08283)

# %% [markdown]
# Limiting the distance between our source and destinations to 1 mile, as no one would go for a ride within 1 mile.

# %%
distance = vincenty(start_loc, end_loc).miles
# We set the condition that the distance should be greater than 1 mile for entering the loop
if(distance > 1):           
    print(distance, '\n')
    # Calling the api and give the array as the source and destination to get the price estiamtes for a ride
    response = client.get_price_estimates(
    start_latitude= df1['coordinates_latitude'][0],
    start_longitude= df1['coordinates_longitude'][0],
    end_latitude=  df2['coordinates_latitude'][0],
    end_longitude= df2['coordinates_longitude'][0]
    )
    # The json file has price estimate for various type of rides offered by uber
    uber_rides = response.json.get("prices")
    print(uber_rides)
# Out:
# 1.0299291303422835
#
# [{'localized_display_name': 'POOL', 'distance': 2.6, 'display_name': 'POOL', 'product_id': '997acbb5-e102-41e1-b155-9df7de0a73f2', 'high_estimate': 12.0, 'low_estimate': 8.0, 'duration': 540, 'estimate': '$8-11', 'currency_code': 'USD'}, {'localized_display_name': 'uberX', 'distance': 2.6, 'display_name': 'uberX', 'product_id': '55c66225-fbe7-4fd5-9072-eab1ece5e23e', 'high_estimate': 12.0, 'low_estimate': 9.0, 'duration': 540, 'estimate': '$9-12', 'currency_code': 'USD'}, {'localized_display_name': 'uberSUV', 'distance': 2.6, 'display_name': 'uberSUV', 'product_id': '6d318bcc-22a3-4af6-bddd-b409bfce1546', 'high_estimate': 36.0, 'low_estimate': 28.0, 'duration': 540, 'estimate': '$28-36', 'currency_code': 'USD'}, {'localized_display_name': 'uberXL', 'distance': 2.6, 'display_name': 'uberXL', 'product_id': '6f72dfc5-27f1-42e8-84db-ccc7a75f6969', 'high_estimate': 17.0, 'low_estimate': 13.0, 'duration': 540, 'estimate': '$13-17', 'currency_code': 'USD'}, {'localized_display_name': 'UberBLACK', 'distance': 2.6, 'display_name': 'UberBLACK', 'product_id': '6c84fd89-3f11-4782-9b50-97c468b19529', 'high_estimate': 25.0, 'low_estimate': 19.0, 'duration': 540, 'estimate': '$19-25', 'currency_code': 'USD'}, {'localized_display_name': 'uberWAV', 'distance': 2.6, 'display_name': 'uberWAV', 'product_id': '9a0e7b09-b92b-4c41-9779-2ad22b4d779d', 'high_estimate': 12.0, 'low_estimate': 9.0, 'duration': 540, 'estimate': '$9-12', 'currency_code': 'USD'}, {'localized_display_name': 'TAXI', 'distance': 2.6, 'display_name': 'TAXI', 'product_id': '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a', 'high_estimate': None, 'low_estimate': None, 'duration': 540, 'estimate': 'Metered', 'currency_code': None}]

# %% [markdown]
# Setting time and cooridnates to our json file.

# %%
dt = datetime.datetime.now()    
# The following for loop will allow us to iterate through all the rows to add time, day, date, start location, end location and the coordinates
for rides in uber_rides:
    rides["time"] = dt.strftime('%H:%M:%S')
    rides['day'] = dt.strftime('%A')
    rides['date'] = dt.strftime('%B %d, %Y')
    rides["start_latitude"] = df1['coordinates_latitude'][0]
    rides["start_longitude"] = df1['coordinates_longitude'][0]
    rides["end_latitude"] = df2['coordinates_latitude'][0]
    rides["end_longitude"] = df2['coordinates_longitude'][0]
    rides['start_location'] = df1['name'][0]
    rides['end_location'] = df2['name'][0]

# %% [markdown]
# Converting our json file to the data frame and getting the output as a csv file. This will allow us to gather our data for further analysis.

# %%
df_uber = pd.DataFrame(uber_rides)

# to append when sending to server
with open('uber_test.csv', 'a') as f:
    df_uber.to_csv(f, sep=',', encoding='utf-8', index=False, header=False)

# %% [markdown]
# ## Lyft API

# %% [markdown]
# Some imports that are needed to run the Lyft Api

# %%
from lyft_rides.auth import ClientCredentialGrant
from lyft_rides.session import Session as lyft_Session
from lyft_rides.auth import AuthorizationCodeGrant

# %% [markdown]
# Using the same source and destiantion coordinates to get price estimations using the Lyft api for getting comparisons between Uber and Lyft.

# %%
auth_flow = ClientCredentialGrant(
    'gRUenY4LPYg_',
    'dFyiT-f23Jwmo_A7n2xGfzp_WcWvBIi8',
    'public',
    )
lyft_session = auth_flow.get_session()

#Use the same location
df1.head()

df2.head()

#Get the ride type, Introduction to different type of lyft:https://developer.lyft.com/docs/glossary
from lyft_rides.client import LyftRidesClient

lyft_client=LyftRidesClient(lyft_session)
lyft_type_response = lyft_client.get_ride_types(df1['coordinates_latitude'][0], df1['coordinates_longitude'][0])
ride_types = lyft_type_response.json.get('ride_types')
print(ride_types)
# Out:
# [{'display_name': 'Lyft Line', 'category_key': 'courier', 'image_url': 'https://cdn.lyft.com/assets/car_standard.png', 'pricing_details': {'base_charge': 210, 'cost_per_mile': 135, 'cost_per_minute': 21, 'cost_minimum': 350, 'trust_and_service': 185, 'currency': 'USD', 'cancel_penalty_amount': 500}, 'seats': 2, 'ride_type': 'lyft_line'}, {'display_name': 'Lyft', 'category_key': 'standard', 'image_url': 'https://cdn.lyft.com/assets/car_standard.png', 'pricing_details': {'base_charge': 210, 'cost_per_mile': 135, 'cost_per_minute': 21, 'cost_minimum': 500, 'trust_and_service': 185, 'currency': 'USD', 'cancel_penalty_amount': 500}, 'seats': 4, 'ride_type': 'lyft'}, {'display_name': 'Lyft Plus', 'category_key': 'plus', 'image_url': 'https://cdn.lyft.com/assets/car_plus.png', 'pricing_details': {'base_charge': 350, 'cost_per_mile': 250, 'cost_per_minute': 35, 'cost_minimum': 600, 'trust_and_service': 210, 'currency': 'USD', 'cancel_penalty_amount': 500}, 'seats': 6, 'ride_type': 'lyft_plus'}, {'display_name': 'Lyft Premier', 'category_key': 'premium', 'image_url': 'https://cdn.lyft.com/assets/car_plus.png', 'pricing_details': {'base_charge': 430, 'cost_per_mile': 295, 'cost_per_minute': 40, 'cost_minimum': 800, 'trust_and_service': 210, 'currency': 'USD', 'cancel_penalty_amount': 500}, 'seats': 4, 'ride_type': 'lyft_premier'}, {'display_name': 'Lyft Lux', 'category_key': 'lux', 'image_url': 'https://cdn.lyft.com/assets/car_plus.png', 'pricing_details': {'base_charge': 700, 'cost_per_mile': 400, 'cost_per_minute': 45, 'cost_minimum': 1500, 'trust_and_service': 135, 'currency': 'USD', 'cancel_penalty_amount': 1000}, 'seats': 4, 'ride_type': 'lyft_lux'}, {'display_name': 'Lyft Lux SUV', 'category_key': 'luxsuv', 'image_url': 'https://cdn.lyft.com/assets/car_plus.png', 'pricing_details': {'base_charge': 1400, 'cost_per_mile': 435, 'cost_per_minute': 50, 'cost_minimum': 2500, 'trust_and_service': 135, 'currency': 'USD', 'cancel_penalty_amount': 1000}, 'seats': 6, 'ride_type': 'lyft_luxsuv'}]

# %% [markdown]
# Verification of minimum distance

# %%
#Get the ride estimated cost
distance = vincenty(start_loc, end_loc).miles
# We set the condition that the distance should be greater than 1 mile for entering the loop
if(distance > 1):
    print(distance)
    # Calling the api and give the array as the source and destination to get the price estiamtes for a ride
    lyft_price_response = lyft_client.get_cost_estimates(
    start_latitude= df1['coordinates_latitude'][0],
    start_longitude= df1['coordinates_longitude'][0],
    end_latitude=  df2['coordinates_latitude'][0],
    end_longitude= df2['coordinates_longitude'][0]
    )
    # The json file has price estimate for various type of rides offered by Lyft
    lyft_rides = lyft_price_response.json.get('cost_estimates')
    print(lyft_rides)
# Out:
# 1.0299291303422835
# [{'ride_type': 'lyft_line', 'estimated_duration_seconds': 579, 'estimated_distance_miles': 3.1, 'price_quote_id': 'ec59ea917b67f38a341af35fe7f8c1e0d61316d877db34975dd83911e855b76d', 'estimated_cost_cents_max': 367, 'primetime_percentage': '0%', 'is_valid_estimate': True, 'currency': 'USD', 'cost_token': None, 'estimated_cost_cents_min': 367, 'display_name': 'Lyft Line', 'primetime_confirmation_token': None, 'can_request_ride': True}, {'ride_type': 'lyft', 'estimated_duration_seconds': 579, 'estimated_distance_miles': 3.1, 'price_quote_id': 'ec59ea917b67f38a341af35fe7f8c1e0d61316d877db34975dd83911e855b76d', 'estimated_cost_cents_max': 1020, 'primetime_percentage': '0%', 'is_valid_estimate': True, 'currency': 'USD', 'cost_token': None, 'estimated_cost_cents_min': 1020, 'display_name': 'Lyft', 'primetime_confirmation_token': None, 'can_request_ride': True}, {'ride_type': 'lyft_plus', 'estimated_duration_seconds': 579, 'estimated_distance_miles': 3.1, 'price_quote_id': 'ec59ea917b67f38a341af35fe7f8c1e0d61316d877db34975dd83911e855b76d', 'estimated_cost_cents_max': 1679, 'primetime_percentage': '0%', 'is_valid_estimate': True, 'currency': 'USD', 'cost_token': None, 'estimated_cost_cents_min': 1679, 'display_name': 'Lyft Plus', 'primetime_confirmation_token': None, 'can_request_ride': True}, {'ride_type': 'lyft_premier', 'estimated_duration_seconds': 579, 'estimated_distance_miles': 3.1, 'price_quote_id': 'ec59ea917b67f38a341af35fe7f8c1e0d61316d877db34975dd83911e855b76d', 'estimated_cost_cents_max': 1948, 'primetime_percentage': '0%', 'is_valid_estimate': True, 'currency': 'USD', 'cost_token': None, 'estimated_cost_cents_min': 1948, 'display_name': 'Lyft Premier', 'primetime_confirmation_token': None, 'can_request_ride': True}, {'ride_type': 'lyft_lux', 'estimated_duration_seconds': 579, 'estimated_distance_miles': 3.1, 'price_quote_id': 'ec59ea917b67f38a341af35fe7f8c1e0d61316d877db34975dd83911e855b76d', 'estimated_cost_cents_max': 2519, 'primetime_percentage': '0%', 'is_valid_estimate': True, 'currency': 'USD', 'cost_token': None, 'estimated_cost_cents_min': 2519, 'display_name': 'Lyft Lux', 'primetime_confirmation_token': None, 'can_request_ride': True}, {'ride_type': 'lyft_luxsuv', 'estimated_duration_seconds': 579, 'estimated_distance_miles': 3.1, 'price_quote_id': 'ec59ea917b67f38a341af35fe7f8c1e0d61316d877db34975dd83911e855b76d', 'estimated_cost_cents_max': 3379, 'primetime_percentage': '0%', 'is_valid_estimate': True, 'currency': 'USD', 'cost_token': None, 'estimated_cost_cents_min': 3379, 'display_name': 'Lyft Lux SUV', 'primetime_confirmation_token': None, 'can_request_ride': True}]

# %% [markdown]
# Adding date-time and inserting start and end locations to the json file and then converting them to a dataframe and apending them to a csv file.

# %%
# The following for loop will allow us to iterate through all the rows to add time, day, date, start location, end location and the coordinates
for rides in lyft_rides:
    rides["time"] = dt.strftime('%H:%M:%S')
    rides['day'] = dt.strftime('%A')
    rides['date'] = dt.strftime('%B %d, %Y')
    rides["start_latitude"] = df1['coordinates_latitude'][0]
    rides["start_longitude"] = df1['coordinates_longitude'][0]
    rides["end_latitude"] = df2['coordinates_latitude'][0]
    rides["end_longitude"] = df2['coordinates_longitude'][0]
    rides['start_location'] = df1['name'][0]
    rides['end_location'] = df2['name'][0]
# Create a data frame for the lyft
df_lyft = pd.DataFrame(lyft_rides)
df_lyft

file_name_lyft = os.path.join(os.getcwd(), 'lyft_test.csv')
df_lyft.to_csv(file_name_lyft, sep=',', encoding='utf-8', index=False
               
# to append when sending to server
with open('lyft_test.csv', 'a') as f:
    df_lyft.to_csv(f, sep=',', encoding='utf-8', index=False, header=False)

# %% [markdown]
# ## Weather API

# %% [markdown]
# Getting the weather data as a feature to add to our dataset for further analysis.

# %%
#Get the current weather information from lat and long
#http://api.openweathermap.org/data/2.5/weather?lat=42.37046&lon=-71.10352&appid=119fe664452f079528a64467c793dd7d
lat=str(df1['coordinates_latitude'][0])
long=str(df1['coordinates_longitude'][0])

api_address='http://api.openweathermap.org/data/2.5/weather?lat='+lat+'&lon='+long+'&appid=119fe664452f079528a64467c793dd7d&q='

# real_time=time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())

weather_data = requests.get(api_address).json()

print(weather_data)
# print(real_time)
# Out:
# {'coord': {'lon': -71.07, 'lat': 42.35}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 278.23, 'pressure': 1030, 'humidity': 60, 'temp_min': 276.15, 'temp_max': 281.15}, 'visibility': 16093, 'wind': {'speed': 3.1, 'deg': 230}, 'clouds': {'all': 1}, 'dt': 1524557700, 'sys': {'type': 1, 'id': 1274, 'message': 0.0048, 'country': 'US', 'sunrise': 1524563337, 'sunset': 1524612987}, 'id': 4930956, 'name': 'Boston', 'cod': 200}

# %%
weather_data['weather'] = weather_data['weather'][0]['main']
df_weather = json_normalize(weather_data)

# %%
# Changing the name of the columns for ease of use
df_weather.columns = df_weather.columns.str.replace(r'[.]', '_')
df_weather.head()
# Dropping columns that are not usefull
df_weather = df_weather[['weather', 'main_temp', 'main_temp_max', 'main_temp_min']]
df_weather.head()
# Out:
#   weather  main_temp  main_temp_max  main_temp_min
# 0   Clear     278.23         281.15         276.15

# %% [markdown]
# ## License

# %% [markdown]
# The content of this project itself is licensed under the Creative Commons Attribution 3.0 license, and the underlying source code used to format and display that content is licensed under the [MIT License](https://github.com/rahilshah10/IS/blob/master/LICENSE).
